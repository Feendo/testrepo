# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **David Feenstra**
# Business Inelligence Manager

# %% [markdown]
# *I am interested in this Data Science course to add a credential to my current position. This will make it easier for me to get my current employer to fund an MBA program*

# %% [markdown]
# ### The cell below is doing simple math

# %%
1+1

# %% [markdown]
# 1. This is the first thing
# 2. This is the second
# - This is a bullet
# - Here is another bullet
# ---
#  > Never trust what you read on the internet. - Abe Lincoln
